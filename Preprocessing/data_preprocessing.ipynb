# %% [markdown]
# # **Data Preprocessing**

# %% [markdown]
# ### **Import**

# %%
import pandas as pd

# %% [markdown]
# ### **Load Dataset**

# %%
df = pd.read_csv('../movie_dataset.csv')

# %% [markdown]
# ### **Understanding the Data**
